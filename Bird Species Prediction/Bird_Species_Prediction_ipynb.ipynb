# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls"/content/drive/My Drive"
# Out:
# /bin/bash: line 1: ls/content/drive/My Drive: No such file or directory

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from matplotlib.image import imread
import random
from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array,array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Activation,Flatten,Dropout,Dense
from sklearn.model_selection import train_test_split

# %%
plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Bird Speciees Dataset/AMERICAN GOLDFINCH"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %%
dir = "/content/drive/My Drive/Bird Speciees Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %%
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = cv2.imread(image_path)
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %%
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# 0
# AMERICAN GOLDFINCH    143
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# FLAMINGO              132
# CARMINE BEE-EATER     131
# BARN OWL              129
# Name: count, dtype: int64

# %%
num_classes=len(label_counts)
num_classes
# Out:
# 6

# %%
image_list[0].shape
# Out:
# (224, 224, 3)

# %%
label_list=np.array(label_list)
label_list.shape
# Out:
# (811,)

# %%
x_train,x_test,y_train,y_test=train_test_split(image_list,label_list,test_size=0.2,random_state=10)

# %%
x_train=np.array(x_train,dtype=np.float16)/225.0
x_test=np.array(x_test,dtype=np.float16)/225.0
x_train=x_train.reshape(-1,224,224,3)
x_test=x_test.reshape(-1,224,224,3)

# %%
lb=LabelBinarizer()
y_train=lb.fit_transform(y_train)
y_test=lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']

# %%
x_train,x_val,y_train,y_val=train_test_split(x_train,y_train,test_size=0.2)

# %%
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same",input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 8)    │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 74, 74, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 37, 37, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 37, 37, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 18, 18, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 10368)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │       331,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 338,038 (1.29 MB)
#  Trainable params: 338,038 (1.29 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(0.0005),metrics=['accuracy'])

# %%
epochs=50
batch_size=128
history=model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,validation_data=(x_val,y_val))
# Out:
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 17s 3s/step - accuracy: 0.9838 - loss: 0.0863 - val_accuracy: 0.8154 - val_loss: 0.5204
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - accuracy: 0.9933 - loss: 0.0640 - val_accuracy: 0.8308 - val_loss: 0.4986
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.9990 - loss: 0.0454 - val_accuracy: 0.8308 - val_loss: 0.5411
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9979 - loss: 0.0512 - val_accuracy: 0.8077 - val_loss: 0.5579
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.9973 - loss: 0.0372 - val_accuracy: 0.8231 - val_loss: 0.5338
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/step - accuracy: 0.9929 - loss: 0.0498 - val_accuracy: 0.7846 - val_loss: 0.6232
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.9990 - loss: 0.0398 - val_accuracy: 0.7923 - val_loss: 0.5967
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.9965 - loss: 0.0399 - val_accuracy: 0.8077 - val_loss: 0.5392
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 1.0000 - loss: 0.0246 - val_accuracy: 0.8231 - val_loss: 0.5601
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0255 - val_accuracy: 0.8385 - val_loss: 0.5245
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0216 - val_accuracy: 0.8154 - val_loss: 0.5230
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - accuracy: 1.0000 - loss: 0.0209 - val_accuracy: 0.8231 - val_loss: 0.5147
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 1.0000 - loss: 0.0202 - val_accuracy: 0.8308 - val_loss: 0.5098
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0179 - val_accuracy: 0.8308 - val_loss: 0.5200
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 1.0000 - loss: 0.0171 - val_accuracy: 0.8308 - val_loss: 0.5214
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 32s 5s/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 0.8231 - val_loss: 0.5110
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.8231 - val_loss: 0.5182
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.8231 - val_loss: 0.5161
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.8308 - val_loss: 0.5210
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.8308 - val_loss: 0.5126
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 0.8308 - val_loss: 0.5152
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.8308 - val_loss: 0.5141
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.8231 - val_loss: 0.5137
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.8385 - val_loss: 0.5153
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.8154 - val_loss: 0.5259
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 0.8308 - val_loss: 0.5316
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.8231 - val_loss: 0.5251
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.8462 - val_loss: 0.5688
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.8385 - val_loss: 0.5341
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.8462 - val_loss: 0.5525
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.8154 - val_loss: 0.5298
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.8231 - val_loss: 0.5314
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.8308 - val_loss: 0.5278
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.8231 - val_loss: 0.5290
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.8231 - val_loss: 0.5341
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.8308 - val_loss: 0.5235
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.8385 - val_loss: 0.5243
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.8308 - val_loss: 0.5227
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.8308 - val_loss: 0.5378
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.8462 - val_loss: 0.5282
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.8462 - val_loss: 0.5285
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.8385 - val_loss: 0.5335
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.8308 - val_loss: 0.5325
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.8231 - val_loss: 0.5295
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.8308 - val_loss: 0.5347
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.8385 - val_loss: 0.5292
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.8462 - val_loss: 0.5332
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.8308 - val_loss: 0.5315
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 5s/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.8462 - val_loss: 0.5362
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.8385 - val_loss: 0.5391

# %%
model.save("/content/drive/My Drive/bird_species.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
plt.figure(figsize=(12,5))
plt.plot(history.history['accuracy'],color='r')
plt.plot(history.history['val_accuracy'],color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','val'])
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
score=model.evaluate(x_test,y_test)
print(f"Test Accuracy: {score[1]*100}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - accuracy: 0.8781 - loss: 0.3893
# Test Accuracy: 88.3435606956482

# %%
y_pred=model.predict(x_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 373ms/step

# %%
img=array_to_img(x_test[5])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[5])])
print("Predicted : ",labels[np.argmax(y_pred[5])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  CARMINE BEE-EATER
# Predicted :  CARMINE BEE-EATER
